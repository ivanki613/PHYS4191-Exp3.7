# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# %%
data=np.loadtxt('wafera_1_combine.csv', delimiter=",",skiprows=1)
V_exp_1=data.T[0]
I_exp_1=data.T[1]

data=np.loadtxt('wafera_2_combine.csv', delimiter=",",skiprows=1)
V_exp_2=data.T[0]
I_exp_2=data.T[1]

data=np.loadtxt('wafera_10_combine.csv', delimiter=",",skiprows=1)
V_exp_10=data.T[0]
I_exp_10=data.T[1]

data=np.loadtxt('wafera_15_combine.csv', delimiter=",",skiprows=1)
V_exp_15=data.T[0]
I_exp_15=data.T[1]

data=np.loadtxt('wafera_17_combine.csv', delimiter=",",skiprows=1)
V_exp_17=data.T[0]
I_exp_17=data.T[1]

plt.scatter(V_exp_1,I_exp_1, s=10,label='1')
plt.scatter(V_exp_2,I_exp_2, s=10,label='2')
plt.scatter(V_exp_10,I_exp_10, s=10,label='10')
plt.scatter(V_exp_15,I_exp_15, s=10,label='15')
plt.scatter(V_exp_17,I_exp_17, s=10,label='17')
plt.grid()
plt.xlabel('Voltage (V)')
plt.ylabel('Current (A)')
plt.legend(loc='best')
plt.show()
