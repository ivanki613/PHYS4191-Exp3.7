# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# %%
data=np.loadtxt('3.7waferb_1st_test.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_1=data.T[0]
C_exp_1=data.T[1]

#print(V_exp)
print("Voltage: ", V_exp_1)
print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_1,C_exp_1)
plt.grid()
plt.show()
# Out:
# Voltage:  [-10.128 -10.04   -9.941  -9.842  -9.744  -9.645  -9.545  -9.447  -9.348
#   -9.249  -9.15   -9.051  -8.951  -8.853  -8.754  -8.655  -8.556  -8.457
#   -8.357  -8.258  -8.159  -8.06   -7.862  -7.763  -7.663  -7.565  -7.466
#   -7.367  -7.268  -7.169  -7.07   -6.971  -6.872  -6.773  -6.674  -6.575
#   -6.476  -6.377  -6.278  -6.179  -6.08   -5.981  -5.882  -5.784  -5.684
#   -5.585  -5.487  -5.287  -5.183  -5.183  -5.084  -4.985  -4.886  -4.787
#   -4.688  -4.589  -4.391  -4.292  -4.192  -4.094  -3.994  -3.895  -3.796
#   -3.697  -3.599  -3.5    -3.401  -3.302  -3.203  -3.104  -3.004  -2.906
#   -2.807  -2.708  -2.609  -2.51   -2.411  -2.312  -2.213  -2.115  -2.015
#   -1.817  -1.718  -1.718  -1.619  -1.52   -1.421  -1.322  -1.223  -1.124
#   -0.926  -0.827  -0.728  -0.629  -0.529  -0.43   -0.331  -0.233  -0.134
#   -0.034   0.064   0.163   0.262   0.361   0.46    0.559   0.658   0.757
#    0.856   0.955   1.054   1.153   1.252   1.351   1.45    1.549   1.648
# ...

# %%
data=np.loadtxt('3.7waferb_2nd_test.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_2=data.T[0]
C_exp_2=data.T[1]
#print("Voltage: ", V_exp_2)
#print("Capacitance: ", C_exp_2)
plt.scatter(V_exp_2,C_exp_2)
plt.grid()
plt.show()

# %%
data=np.loadtxt('3.7waferb_3rd_test.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_3=data.T[0]
C_exp_3=data.T[1]
plt.scatter(V_exp_3,C_exp_3)
plt.grid()
plt.show()

# %%
data=np.loadtxt('3.7waferb_4th_test.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_4=data.T[0]
C_exp_4=data.T[1]
plt.scatter(V_exp_4,C_exp_4)
plt.grid()
plt.show()

# %%
data=np.loadtxt('3.7waferb_5th_test.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_5=data.T[0]
C_exp_5=data.T[1]
plt.scatter(V_exp_5,C_exp_5)
plt.grid()
plt.show()

# %%
plt.scatter(V_exp_1,C_exp_1, s=10,label='1st electrode')
plt.scatter(V_exp_2,C_exp_2, s=10,label='2nd electrode')
plt.scatter(V_exp_3,C_exp_3, s=10,label='3rd electrode')
plt.scatter(V_exp_4,C_exp_4, s=10,label='4th electrode')
plt.scatter(V_exp_5,C_exp_5, s=10,label='5th electrode')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()
