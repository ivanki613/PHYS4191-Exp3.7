# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt

# %%
data=np.loadtxt('waferb_1.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_1=data.T[0]
C_exp_1=data.T[1]

#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_1,C_exp_1)
#plt.grid()
plt.show()

# %%
data=np.loadtxt('waferb_4_2.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_4_2=data.T[0]
C_exp_4_2=data.T[1]

data=np.loadtxt('waferb_4_3.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_4_3=data.T[0]
C_exp_4_3=data.T[1]

#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_4_2,C_exp_4_2)
#plt.grid()
plt.show()

plt.scatter(V_exp_4_3,C_exp_4_3)
plt.show()

# %%
data=np.loadtxt('waferb_5.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_5=data.T[0]
C_exp_5=data.T[1]


#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_5,C_exp_5)
#plt.grid()
plt.show()

# %%
data=np.loadtxt('waferb_14.csv', delimiter=",",skiprows=2)
data=np.loadtxt('waferb_14_2.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_14=data.T[0]
C_exp_14=data.T[1]

V_exp_14_2=data.T[0]
C_exp_14_2=data.T[1]


#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_14,C_exp_14)
#plt.grid()
plt.show()

plt.scatter(V_exp_14_2,C_exp_14_2)
#plt.grid()
plt.show()

# %%
data=np.loadtxt('waferb_15.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_15=data.T[0]
C_exp_15=data.T[1]


#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_15,C_exp_15)
#plt.grid()
plt.show()

# %%
data=np.loadtxt('waferb_16.csv', delimiter=",",skiprows=2)
data=np.loadtxt('waferb_16_2.csv', delimiter=",",skiprows=2)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_16=data.T[0]
C_exp_16=data.T[1]

V_exp_16_2=data.T[0]
C_exp_16_2=data.T[1]


#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_16,C_exp_16)
#plt.grid()
plt.show()

plt.scatter(V_exp_16_2,C_exp_16_2)
#plt.grid()
plt.show()

# %%
data=np.loadtxt('waferb_17.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_17=data.T[0]
C_exp_17=data.T[1]


#print(V_exp)
#print("Voltage: ", V_exp_1)
#print("Capacitance: ", C_exp_1)
plt.scatter(V_exp_17,C_exp_17)
#plt.grid()
plt.show()

# %%
plt.scatter(V_exp_1,C_exp_1, s=10,label='1')
#plt.scatter(V_exp_4_2,C_exp_4_2,s=10,label='4_2')
#plt.scatter(V_exp_4_3,C_exp_4_3,s=10,label='4_3')
plt.scatter(V_exp_5,C_exp_5,s=10,label='5')
plt.scatter(V_exp_14,C_exp_14,s=10,label='14')
#plt.scatter(V_exp_14_2,C_exp_14_2,s=10,label='14_2')
plt.scatter(V_exp_15,C_exp_15,s=10,label='15')
plt.scatter(V_exp_16,C_exp_16,s=10,label='16')
#plt.scatter(V_exp_16_2,C_exp_16_2,s=10,label='16_2')
plt.scatter(V_exp_17,C_exp_17,s=10,label='17')

plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

plt.scatter(V_exp_1,C_exp_1, s=10,label='1')
plt.scatter(V_exp_5,C_exp_5,s=10,label='5')
plt.scatter(V_exp_16,C_exp_16,s=10,label='16')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

plt.scatter(V_exp_1,C_exp_1, s=10,label='1')
plt.scatter(V_exp_5,C_exp_5,s=10,label='5')
plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

#print('V_1: ', V_exp_1)
#print('C_1: ', C_exp_1)

#print('V_2: ', V_exp_5)
#print('C_2: ', C_exp_5)

# %%
data=np.loadtxt('waferb_1_light.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_1_light=data.T[0]
C_exp_1_light=data.T[1]

data=np.loadtxt('waferb_15_light.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_15_light=data.T[0]
C_exp_15_light=data.T[1]

data=np.loadtxt('waferb_17_light.csv', delimiter=",",skiprows=1)
#data=np.loadtxt('3.7wafera2nd_test.csv', delimiter=",")
V_exp_17_light=data.T[0]
C_exp_17_light=data.T[1]

# %%
plt.scatter(V_exp_1,C_exp_1, s=10,label='1')
plt.scatter(V_exp_1_light,C_exp_1_light,s=10,label='1_light')

plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

plt.scatter(V_exp_15,C_exp_15, s=10,label='15')
plt.scatter(V_exp_15_light,C_exp_15_light,s=10,label='15_light')

plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()

plt.scatter(V_exp_17,C_exp_17, s=10,label='17')
plt.scatter(V_exp_17_light,C_exp_17_light,s=10,label='17_light')

plt.xlabel('Voltage (V)')
plt.ylabel('Capacitance (F)')
plt.grid()
plt.legend(loc='best')
plt.show()
